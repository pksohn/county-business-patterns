# %%
from __future__ import division
import sys
sys.path.append('./../cbp')
import utils
import cbp
import pandas as pd
import secrets
from cbp import Counties

# %%
# Example code for downloading from Census API
# texas_api = Counties(state_fips='48', read_from='api', key=secrets.censuskey)
# texas_api.head()
# texas_api.to_csv('texas_cbp_2014.csv', index=False)

# %%
# Instantiate Counties object for Texas 2014
texas = Counties(state_fips='48', read_from='csv', filepath='texas_cbp_2014.csv')
texas.head()
# Out:
#      EMP  ESTAB NAICS2012          NAICS2012_TTL          GEO_TTL state county
# 0  11738    940        00  Total for all sectors  Anderson County    48    001
# 1   5683    403        00  Total for all sectors   Andrews County    48    003
# 2  30525   1857        00  Total for all sectors  Angelina County    48    005
# 3   4131    503        00  Total for all sectors   Aransas County    48    007
# 4   1539    201        00  Total for all sectors    Archer County    48    009

# %%
# Identify FIPS codes for our five Austin-Round Rock MSA counties from the data

fips = []
for county in "Bastrop, Caldwell, Hays, Travis, Williamson".split(", "):
    fips.append(texas[(texas.NAICS2012 == '00') & (texas.GEO_TTL.str.contains(county))]['county'].iloc[0])
print fips
# Out:
# ['021', '055', '209', '453', '491']

# %%
# Get data at the two-digit NAICS level, for only the Austin MSA counties
austin_region = texas.three_digit(county=fips)
austin_region.head()
# Out:
#         EMP  ESTAB NAICS2012          NAICS2012_TTL            GEO_TTL state  \
# 10    12475   1175        00  Total for all sectors     Bastrop County    48
# 27     6116    580        00  Total for all sectors    Caldwell County    48
# 104   46675   3660        00  Total for all sectors        Hays County    48
# 225  544038  32217        00  Total for all sectors      Travis County    48
# 244  136393   9252        00  Total for all sectors  Williamson County    48
#
#     county
# 10     021
# 27     055
# 104    209
# 225    453
# 244    491

# %%
austin_all = texas.get_county(fips)

# %%
# Use groupby to aggregate data into MSA-level totals

aggs = {
    'EMP':'sum',
    'ESTAB':'sum',
    'NAICS2012_TTL':'first'
}
austin_msa = austin_region.groupby('NAICS2012',as_index=False).agg(aggs)
austin_msa['GEO_TTL'] = 'Austin-Round Rock MSA'
austin_msa.head()
# Out:
#   NAICS2012                                    NAICS2012_TTL  ESTAB     EMP  \
# 0        00                            Total for all sectors  46884  745697
# 1       114                    Fishing, Hunting and Trapping      1      10
# 2       115  Support Activities for Agriculture and Forestry     27      60
# 3       211                           Oil and Gas Extraction     95     607
# 4       212                      Mining (except Oil and Gas)     30    1051
#
#                  GEO_TTL
# 0  Austin-Round Rock MSA
# 1  Austin-Round Rock MSA
# 2  Austin-Round Rock MSA
# 3  Austin-Round Rock MSA
# 4  Austin-Round Rock MSA

# %%
# Use groupby to aggregate data into MSA-level totals

aggs = {
    'EMP':'sum',
    'ESTAB':'sum',
    'NAICS2012_TTL':'first'
}
austin_msa_all = austin_all.groupby('NAICS2012',as_index=False).agg(aggs)
austin_msa_all['GEO_TTL'] = 'Austin-Round Rock MSA'
austin_msa_all.head()
# Out:
#   NAICS2012                               NAICS2012_TTL  ESTAB     EMP  \
# 0        00                       Total for all sectors  46884  745697
# 1        11  Agriculture, Forestry, Fishing and Hunting     28      61
# 2       114               Fishing, Hunting and Trapping      1      10
# 3      1142                        Hunting and Trapping      1      10
# 4     11421                        Hunting and Trapping      1      10
#
#                  GEO_TTL
# 0  Austin-Round Rock MSA
# 1  Austin-Round Rock MSA
# 2  Austin-Round Rock MSA
# 3  Austin-Round Rock MSA
# 4  Austin-Round Rock MSA

# %%
# LOCATION QUOTIENT

# Create series for employment by sector for Texas
texas_total_emp = texas.three_digit().groupby('NAICS2012').agg('sum').EMP
# Create series for employment by sector for Austin
austin_msa_emp = austin_msa.set_index('NAICS2012').EMP

# Use utils.location_quotient to calculate LQ
lq = pd.DataFrame(utils.location_quotient(austin_msa_emp, texas_total_emp))

# Merge LQ results into our DataFrame
austin_msa = austin_msa.merge(lq, left_on='NAICS2012', right_index=True)

# %%
# View results
austin_msa.sort_values('location_quotient', ascending=False)
# Out:
#    NAICS2012                                      NAICS2012_TTL  ESTAB    EMP  \
# 60       519                         Other Information Services    125   2145
# 55       511            Publishing Industries (except Internet)    270   9213
# 26       334      Computer and Electronic Product Manufacturing    136  14705
# 59       518     Data Processing, Hosting, and Related Services    160   9572
# 49       485        Transit and Ground Passenger Transportation     62   3310
# 45       454                                 Nonstore Retailers    468   4826
# 67       533  Lessors of Nonfinancial Intangible Assets (exc...     24    551
# 56       512      Motion Picture and Sound Recording Industries    214   2518
# 68       541   Professional, Scientific, and Technical Services   7984  78996
# 33       425  Wholesale Electronic Markets and Agents and Br...    222   2796
# 80       721                                      Accommodation    362  13374
# 4        212                        Mining (except Oil and Gas)     30   1051
# 14       315                              Apparel Manufacturing     14    395
# 83       812                      Personal and Laundry Services   1395  10431
# 65       531                                        Real Estate   2314  12448
# 44       453                      Miscellaneous Store Retailers    595   5404
# 77       711  Performing Arts, Spectator Sports, and Related...    316   2645
# 79       713     Amusement, Gambling, and Recreation Industries    456   9223
# 72       611                               Educational Services    846  16795
# 70       561                Administrative and Support Services   2295  64784
# 42       451  Sporting Goods, Hobby, Musical Instrument, and...    269   4330
# 29       337        Furniture and Related Product Manufacturing     89   2122
# 41       448           Clothing and Clothing Accessories Stores   1006  13753
# 63       524          Insurance Carriers and Related Activities   1199  15000
# 30       339                        Miscellaneous Manufacturing    142   2735
# 38       445                           Food and Beverage Stores    648  21079
# 81       722                  Food Services and Drinking Places   3854  84380
# 64       525        Funds, Trusts, and Other Financial Vehicles      8     70
# 84       813  Religious, Grantmaking, Civic, Professional, a...   1648  17988
# 27       335  Electrical Equipment, Appliance, and Component...     36   1535
# ..       ...                                                ...    ...    ...
# 61       522       Credit Intermediation and Related Activities   1235  14521
# 43       452                         General Merchandise Stores    199  13580
# 11       312         Beverage and Tobacco Product Manufacturing     58    647
# 78       712  Museums, Historical Sites, and Similar Institu...     30    481
# 51       487              Scenic and Sightseeing Transportation      9     32
# 32       424             Merchant Wholesalers, Nondurable Goods    511   7392
# 6        221                                          Utilities    116   2457
# 25       333                            Machinery Manufacturing     77   3949
# 16       321                         Wood Product Manufacturing     43    850
# 13       314                              Textile Product Mills     26    205
# 20       325                             Chemical Manufacturing     47   2086
# 10       311                                 Food Manufacturing    128   2536
# 48       484                               Truck Transportation    362   3768
# 21       326         Plastics and Rubber Products Manufacturing     31   1090
# 1   Austin-Round Rock MSA           0.173260
# 3   Austin-Round Rock MSA           0.153175
# 2   Austin-Round Rock MSA           0.103649
# 50  Austin-Round Rock MSA           0.100393
# 5   Austin-Round Rock MSA           0.069995
# 17  Austin-Round Rock MSA           0.069197
# 47  Austin-Round Rock MSA           0.045682
# 19  Austin-Round Rock MSA           0.033359
#
# [85 rows x 6 columns]

# %%
lq = pd.DataFrame(utils.location_quotient(austin_msa_all.set_index('NAICS2012').EMP,
                                          texas.groupby('NAICS2012').agg('sum').EMP))

# Merge LQ results into our DataFrame
austin_msa_all = austin_msa_all.merge(lq, left_on='NAICS2012', right_index=True)

# %%
# Clusters
movies = austin_msa_all[austin_msa_all.NAICS2012.str.startswith('512') | 
                        austin_msa_all.NAICS2012.str.startswith('515') |
                        austin_msa_all.NAICS2012.str.startswith('517')]

# %%
movies[(movies.location_quotient > 1) & (movies.NAICS2012.str.len() == 5)]
# Out:
#      NAICS2012                                      NAICS2012_TTL  ESTAB  \
# 1077     51211                Motion Picture and Video Production    124
# 1081     51213                Motion Picture and Video Exhibition     37
# 1084     51219  Postproduction Services and Other Motion Pictu...     26
# 1088     51221                                  Record Production      1
# 1094     51224                            Sound Recording Studios     18
# 1096     51229                   Other Sound Recording Industries      3
# 1103     51512                            Television Broadcasting     11
# 1107     51711                  Wired Telecommunications Carriers    193
# 1116     51791                           Other Telecommunications     39
#
#        EMP                GEO_TTL  location_quotient
# 1077   527  Austin-Round Rock MSA           2.817354
# 1081  1807  Austin-Round Rock MSA           1.475074
# 1084    97  Austin-Round Rock MSA           1.211157
# 1088    10  Austin-Round Rock MSA           2.574644
# 1094    80  Austin-Round Rock MSA           2.340586
# 1096    20  Austin-Round Rock MSA           2.076326
# 1103   768  Austin-Round Rock MSA           1.194326
# 1107  5801  Austin-Round Rock MSA           1.064071
# 1116   400  Austin-Round Rock MSA           1.096527

# %%
computers = austin_msa_all[austin_msa_all.NAICS2012.str.startswith('334')]

# %%
# computers[(computers.location_quotient > 1) & (computers.NAICS2012.str.len() == 5)]
computers[(computers.NAICS2012.str.len() == 5)]
# Out:
#     NAICS2012                                      NAICS2012_TTL  ESTAB  \
# 482     33411    Computer and Peripheral Equipment Manufacturing     13
# 486     33421                  Telephone Apparatus Manufacturing      5
# 488     33422  Radio and Television Broadcasting and Wireless...      3
# 490     33429       Other Communications Equipment Manufacturing      5
# 493     33431            Audio and Video Equipment Manufacturing      4
# 496     33441  Semiconductor and Other Electronic Component M...     53
# 503     33451  Navigational, Measuring, Electromedical, and C...     49
# 513     33461  Manufacturing and Reproducing Magnetic and Opt...      4
#
#        EMP                GEO_TTL  location_quotient
# 482    343  Austin-Round Rock MSA           1.934085
# 486   1760  Austin-Round Rock MSA           5.109804
# 488     70  Austin-Round Rock MSA           0.306714
# 490    235  Austin-Round Rock MSA           3.372583
# 493     30  Austin-Round Rock MSA           1.119411
# 496  10170  Austin-Round Rock MSA           3.457199
# 503   2518  Austin-Round Rock MSA           0.907291
# 513     20  Austin-Round Rock MSA           0.705382

# %%
austin_msa.to_csv('austin_msa_2014_threedigit_LQ.csv')

# %%
# Get four digit

fourdigit = texas.four_digit(county=fips)

# Use groupby to aggregate data into MSA-level totals

aggs = {
    'EMP':'sum',
    'ESTAB':'sum',
    'NAICS2012_TTL':'first'
}
austin_msa_4 = fourdigit.groupby('NAICS2012',as_index=False).agg(aggs)
austin_msa_4['GEO_TTL'] = 'Austin-Round Rock MSA'
austin_msa_4.head()

# Use utils.location_quotient to calculate LQ
lq = pd.DataFrame(utils.location_quotient(austin_msa_4.set_index('NAICS2012').EMP,
                                          texas.four_digit().groupby('NAICS2012').agg('sum').EMP))

austin_msa_4 = austin_msa_4.merge(lq, left_on='NAICS2012', right_index=True)
austin_msa_4.head()
# Out:
#   NAICS2012                             NAICS2012_TTL  ESTAB     EMP  \
# 0        00                     Total for all sectors  46884  745697
# 1      1142                      Hunting and Trapping      1      10
# 2      1151    Support Activities for Crop Production      7      40
# 3      1152  Support Activities for Animal Production     19      52
# 4      1153           Support Activities for Forestry      1      10
#
#                  GEO_TTL  location_quotient
# 0  Austin-Round Rock MSA           1.000000
# 1  Austin-Round Rock MSA           0.286072
# 2  Austin-Round Rock MSA           0.092248
# 3  Austin-Round Rock MSA           0.325271
# 4  Austin-Round Rock MSA           0.401035

# %%
austin_msa_4.to_csv('./austin_msa_2014_fourdigit_LQ.csv')

# %%
austin_msa_4.sort_values('EMP', ascending=False)
# Out:
#     NAICS2012                                      NAICS2012_TTL  ESTAB  \
# 0          00                              Total for all sectors  46884
# 261      7225                Restaurants and Other Eating Places   3194
# 217      5617                Services to Buildings and Dwellings    952
# 213      5613                                Employment Services    351
# 205      5415       Computer Systems Design and Related Services   1705
# 210      5511            Management of Companies and Enterprises    346
# 229      6211                              Offices of Physicians   1336
# 203      5413   Architectural, Engineering, and Related Services   1099
# 19       2382                     Building Equipment Contractors    991
# 128      4451                                     Grocery Stores    402
# 256      7211                             Traveler Accommodation    295
# 133      4481                                    Clothing Stores    709
# 206      5416  Management, Scientific, and Technical Consulti...   1666
# 270      8131                            Religious Organizations    816
# 83       3344  Semiconductor and Other Electronic Component M...     53
# 190      5241                                 Insurance Carriers    366
# 201      5411                                     Legal Services   1403
# 255      7139          Other Amusement and Recreation Industries    420
# 214      5614                          Business Support Services    228
# 106      4236  Household Appliances and Electrical and Electr...    261
# 185      5221                   Depository Credit Intermediation    623
# 120      4411                                 Automobile Dealers    224
# 104      4234  Professional and Commercial Equipment and Supp...    262
# 183      5182     Data Processing, Hosting, and Related Services    160
# 234      6216                          Home Health Care Services    170
# 139      4529                   Other General Merchandise Stores    162
# 246      6244                            Child Day Care Services    434
# 262      8111                  Automotive Repair and Maintenance    818
# 195      5313                  Activities Related to Real Estate    669
# 175      5112                                Software Publishers    160
# ..        ...                                                ...    ...
# 41       3212  Veneer, Plywood, and Engineered Wood Product M...      5
# 177      5122                         Sound Recording Industries     25
# 40       3211                     Sawmills and Wood Preservation      3
# 181      5174                       Satellite Telecommunications      1
# 39       3169     Other Leather and Allied Product Manufacturing      3
# 28       3117          Seafood Product Preparation and Packaging      3
# 184      5191                         Other Information Services    125
# 38       3161             Leather and Hide Tanning and Finishing      1
# 164       0  Austin-Round Rock MSA
# 157       0  Austin-Round Rock MSA
# 159       0  Austin-Round Rock MSA
# 160       0  Austin-Round Rock MSA
# 161       0  Austin-Round Rock MSA
# 223       0  Austin-Round Rock MSA
# 22        0  Austin-Round Rock MSA
# 52        0  Austin-Round Rock MSA
#
# [275 rows x 5 columns]

# %%
fourdigit.head()
# Out:
# Empty DataFrame
# Columns: [EMP, ESTAB, NAICS2012, NAICS2012_TTL, GEO_TTL, state, county]
# Index: []

# %%
# Get 2006 data for change-over-time analysis
texas06 = Counties(state_fips='48', year=2006, read_from='csv', filepath='texas_cbp_2006.csv')

# Get Austin counties and aggregate to MSA
austin_region_06 = texas06.three_digit(county=fips)
austin_msa_06 = austin_region_06.groupby('NAICS2012',as_index=False).agg('sum')
austin_msa_06['GEO_TTL'] = 'Austin-Round Rock MSA'

# %%
# Clean up Austin 2006 DataFrame
austin_msa_06 = austin_msa_06.merge(austin_msa[['NAICS2012', 'NAICS2012_TTL']], on='NAICS2012')
austin_msa_06.drop('old_naics', axis=1, inplace=True)

# %%
austin_msa_06.head()
# Out:
#   NAICS2012  Unnamed: 0     EMP  ESTAB                GEO_TTL  \
# 0        00      331581  595807  36026  Austin-Round Rock MSA
# 1       114      128035      10      1  Austin-Round Rock MSA
# 2       115      331591      80     19  Austin-Round Rock MSA
# 3       211      331613     260     69  Austin-Round Rock MSA
# 4       212      331626     832     28  Austin-Round Rock MSA
#
#                                      NAICS2012_TTL
# 0                            Total for all sectors
# 1                    Fishing, Hunting and Trapping
# 2  Support Activities for Agriculture and Forestry
# 3                           Oil and Gas Extraction
# 4                      Mining (except Oil and Gas)

# %%
subset06 = austin_msa_06[['NAICS2012', 'EMP', 'ESTAB']].rename(columns={'EMP':'EMP2006', 'ESTAB':'ESTAB2006'})
merged = austin_msa.merge(subset06, on='NAICS2012')

# %%
merged.to_csv('austin_msa_2006_2014_threedigit.csv')

# %%
# Get 2006 series for MSA and Texas employment by sector
austin_msa_emp_06 = austin_msa_06.set_index('NAICS2012').EMP
texas_total_emp_06 = texas06.two_digit().groupby('NAICS2012').agg('sum').EMP

# %%
# Location Quotient for 2006
lq_06 = pd.DataFrame(utils.location_quotient(austin_msa_emp_06, texas_total_emp_06))
austin_msa_06 = austin_msa_06.merge(lq_06, left_on='NAICS2012', right_index=True)

# %%
# Pass the 4 series (2014 and 2006 employment for Texas and for Austin MSA) to shift share function from utils
shift_share, shift_share_summary = utils.shift_share(small_old=austin_msa_emp_06,
                                                     small_new=austin_msa_emp,
                                                     large_old=texas_total_emp_06,
                                                     large_new=texas_total_emp)

# %%
# View detailed results by sector
shift_share
# Out:
#            small_old  small_new  large_old  large_new  large_growth_share  \
# NAICS2012
# 00            609646     745697    8711361    9598578        62089.987452
# 11                55         21       5343       3902            5.601528
# 21              1439       2440     141126     195803          146.556349
# 22               789       2282      28784      35955           80.356469
# 23             41128      45334     551643     581674         4188.721002
# 31-33          50637      42592     835966     772668         5157.174319
# 42             39017      34186     462570     496565         3973.724162
# 44-45          82717      98831    1127808    1239705         8424.392995
# 48-49          11020      13551     349109     395123         1122.342575
# 51             24084      31857     254004     223880         2452.858311
# 52             31350      34508     452476     479880         3192.871120
# 53             14400      16794     168241     183204         1466.581950
# 54             59719      78996     551301     649167         6082.139407
# 55              7655      15608     229688     291488          779.630891
# 56             51199      66549     865246     700159         5214.411753
# 61             10612      16735     132905     161762         1080.789420
# 62             67120      89664    1123641    1391095         6835.901421
# 71              8316      12313     106499     125031          846.951076
# 72             67745      97914     849731    1067278         6899.555152
# 81             31873      37594     405529     432670         3246.136561
# 99               147         14       1957        575           14.971357
#
#            large_industry_growth_rate  industry_mix  \
# NAICS2012
# 00                           0.101846      0.000000
# 11                          -0.269699    -20.434955
# 21                           0.387434    410.961068
# 22                           0.249131    116.208254
# 23                           0.054439  -1949.745853
# 31-33                       -0.075718  -8991.326456
# 42                           0.073492  -1106.303199
# 44-45                        0.099216   -217.513678
# 48-49                        0.131804    330.138684
# 51                          -0.118597  -5309.137803
# 52                           0.060565  -1294.172846
# 53                           0.088938   -185.876295
# 54                           0.177518   4519.074185
# 55                           0.269061   1280.028299
# 56                          -0.190798 -14983.066347
# 61                           0.217125   1223.341230
# 62                           0.238024   9140.297810
# 71                           0.174011    600.124596
# 72                           0.256019  10444.429609
# 81                           0.066927  -1112.959666
# 99                          -0.706183   -118.780249
#
#            small_industry_growth_rate  local_competitiveness
# NAICS2012
# 00                           0.223164           73961.012548
# 11                          -0.618182             -19.166573
# 21                           0.695622             443.482583
# 22                           1.892269            1296.435277
# 23                           0.102266            1967.024851
# 31-33                       -0.158876           -4210.847862
# 42                          -0.123818           -7698.420963
# 44-45                        0.194809            7907.120683
# 48-49                        0.229673            1078.518741
# 51                           0.322745           10629.279492
# 52                           0.100734            1259.301727
# 53                           0.166250            1113.294346
# 54                           0.322795            8675.786409
# 55                           1.038929            5893.340810
# 56                           0.299811           25118.654594
# 61                           0.576988            3818.869350
# 62                           0.335876            6567.800769
# 71                           0.480640            2549.924328
# 72                           0.445332           12825.015239
# 81                           0.179494            3587.823105
# 99                          -0.904762             -29.191109

# %%
# View summary
shift_share_summary
# Out:
#                                                              description  \
# small_growth                                 Growth in smaller geography
# large_growth                                  Growth in larger geography
# large_growth_share     Growth attributable to larger geography growth...
# industry_mix                         Growth attributable to industry mix
# local_competitiveness       Growth attributable to local competitiveness
#
#                             absolute  percentage
# small_growth           136761.000000    0.227547
# large_growth           784017.000000    0.090705
# large_growth_share      61211.667818    0.447581
# industry_mix            -7224.713613   -0.052827
# local_competitiveness   82774.045795    0.605246

# %%
# Coefficient of Specialization

# Use utils.location_quotient to calculate LQ
cs_sectors, cs = utils.specialization_coefficient(austin_msa_emp, texas_total_emp)
cs_sectors_06, cs_06 = utils.specialization_coefficient(austin_msa_emp_06, texas_total_emp_06)

# %%
print cs_06, cs
# Out:
# 0.0966522557497 0.111936597686

# %%
austin_msa.to_csv('austin_msa_2014.csv', index=False)
austin_msa_06.to_csv('austin_msa_2006.csv', index=False)
cs_sectors.to_csv('specialization_2014.csv')
cs_sectors_06.to_csv('specialization_2006.csv')
shift_share.to_csv('shift_share_2006_2014.csv')
